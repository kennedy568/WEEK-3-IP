# %%
import os
import pandas as pd
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'cells_geo.csv',
#  'Moringa_Data_Science_Prep_W3_Independent_Project_2020_03_Kennedy_Nganga_Python_Notebook .ipynb',
#  'README.md',
#  'Telcom_dataset.csv',
#  'Telcom_dataset2.csv',
#  'Telcom_dataset3.csv']

# %%
dx = pd.read_csv('Telcom_dataset.csv')
dy = pd.read_csv('Telcom_dataset2.csv')
dv = pd.read_csv('Telcom_dataset3.csv')
dp = pd.read_csv('cells_geo.csv',delimiter=';', index_col=0)

# %%
dx.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
dx.shape
# Out:
# (5001, 10)

# %%
dy.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
dy.columns
# Out:
# Index(['PRODUCT', 'VALUE', 'DATE_TIME', 'CELL_ON_SITE', 'DW_A_NUMBER',
#        'DW_B_NUMBER', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID'],
#       dtype='object')

# %%
dx.columns
# Out:
# Index(['PRODUTC', 'VALUE', 'DATETIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT',
#        'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID'],
#       dtype='object')

# %%
dv.columns
# Out:
# Index(['PRODUCT', 'VALUE', 'DATE_TIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT',
#        'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELLID', 'SIET_ID'],
#       dtype='object')

# %%
dy.shape
# Out:
# (5001, 10)

# %%
dv.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
dv.shape
# Out:
# (5001, 10)

# %%
dp.head(10)
# Out:
#      VILLES      STATUS LOCALISATION     DECOUPZONE   ZONENAME  LONGITUDE  \
# 0    ADJAME  In Service      ABIDJAN   "Abidjan_EST   AGBANNEW  -4.000667
# 1    ADJAME  In Service      ABIDJAN   "Abidjan_EST   AGBANNEW  -4.000667
# 2    ADJAME  In Service      ABIDJAN   "Abidjan_EST   AGBANNEW  -4.000667
# 3   ASSINIE  In Service    INTERIEUR      Grand-EST   ASSINIE"  -3.488467
# 4   ASSINIE  In Service    INTERIEUR      Grand-EST   ASSINIE"  -3.488467
# 5   ASSINIE  In Service    INTERIEUR      Grand-EST   ASSINIE"  -3.488467
# 6  KRIKOREA  In Service    INTERIEUR    Grand-OUEST  KRIKOREA"  -6.627056
# 7     ABOBO  In Service      ABIDJAN  "Abidjan_NORD     NPONON  -4.023583
# 8     ABOBO  In Service      ABIDJAN  "Abidjan_NORD     NPONON  -4.023583
# 9     ABOBO         NaN      ABIDJAN  "Abidjan_NORD     NPONON  -4.023583
#
#    LATITUDE          REGION AREA     CELL_ID   SITE_CODE
# 0  5.368194          LAGUNE  NaN  fbb2e75af3  0bb492ef17
# ...

# %%
dp.shape
# Out:
# (3974, 11)

# %%
dx.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
dy.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
dx.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
dx.shape
# Out:
# (5001, 10)

# %%
dv.shape
# Out:
# (5001, 10)

# %%
dy.shape
# Out:
# (5001, 10)

# %%
df = pd.concat([dx,dy,dv], axis=0)

# %%
df.shape
# Out:
# (15003, 16)

# %%
dp.columns
# Out:
# Index(['VILLES', 'STATUS', 'LOCALISATION', 'DECOUPZONE', 'ZONENAME',
#        'LONGITUDE', 'LATITUDE', 'REGION', 'AREA', 'CELL_ID', 'SITE_CODE'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['PRODUTC', 'VALUE', 'DATETIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT',
#        'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID',
#        'PRODUCT', 'DATE_TIME', 'DW_A_NUMBER', 'DW_B_NUMBER', 'CELLID',
#        'SIET_ID'],
#       dtype='object')

# %%
len(df.CELL_ID.unique()); df.dropna().shape
# Out:
# (0, 16)

# %%
df
# Out:
#      PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     NaN      0                    NaN            3  467333ade2b4b9c
# 4997     NaN     62                    NaN            1  e077a6b74c5053c
# 4998     NaN     32                    NaN            1  77f53c39d27c050
# 4999     NaN     30                    NaN            2  672ce74c418aa7a
# 5000     NaN     60                    NaN            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID PRODUCT  \
# ...

# %%
df.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID PRODUCT  \
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu     NaN
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41     NaN
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi     NaN
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3     NaN
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv     NaN
#
#   DATE_TIME DW_A_NUMBER DW_B_NUMBER CELLID SIET_ID
# 0       NaN         NaN         NaN    NaN     NaN
# ...

# %%
df= df[['CELL_ID','PRODUTC', 'VALUE', 'DATETIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT', 'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'SITE_ID']]

# %%
df.head()
# Out:
#       CELL_ID PRODUTC  VALUE               DATETIME CELL_ON_SITE  \
# 0  /TJNe+Mmtu   Voice      0  2012-05-06 23:04:37.0            1
# 1  /+cKZKIp41     sms      0  2012-05-06 23:05:25.0            0
# 2  /u0FSD+ahi     sms     25  2012-05-06 23:05:41.0            0
# 3  +cNeJzsTp3   Voice     56  2012-05-06 23:05:42.0            1
# 4  051KhYDCpv   Voice     14  2012-05-06 23:06:29.0            1
#
#    DW_A_NUMBER_INT  DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     SITE_ID
# 0  49fae048b547780  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu
# 1  7a54a6eaee19e65  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41
# 2  6008887b0207d82  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi
# 3  7370032e20f4e96  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3
# 4  966ba4656e38e62  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv

# %%
dp.head()
# Out:
#     VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  LONGITUDE  \
# 0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# 4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
#
#    LATITUDE     REGION AREA     CELL_ID   SITE_CODE
# 0  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17
# 1  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17
# 2  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17
# 3  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f
# 4  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f

# %%
df.CELL_ID.nunique()
# Out:
# 2367

# %%
dp.CELL_ID.nunique()
# Out:
# 3916

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x='PRODUTC', y='VALUE', data=df)
# Out:
# <AxesSubplot:xlabel='PRODUTC', ylabel='VALUE'>

# %%
df1 = pd.concat([dp,df],)

# %%
df1.head(5)
# Out:
#     VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  LONGITUDE  \
# 0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# 4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
#
#    LATITUDE     REGION AREA     CELL_ID   SITE_CODE PRODUTC  VALUE DATETIME  \
# 0  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17     NaN    NaN      NaN
# 1  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17     NaN    NaN      NaN
# 2  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17     NaN    NaN      NaN
# 3  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f     NaN    NaN      NaN
# 4  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f     NaN    NaN      NaN
#
#   CELL_ON_SITE DW_A_NUMBER_INT DW_B_NUMBER_INT COUNTRY_A COUNTRY_B SITE_ID
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18977 entries, 0 to 5000
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VILLES           3974 non-null   object
#  1   STATUS           3907 non-null   object
#  2   LOCALISATION     3974 non-null   object
#  3   DECOUPZONE       3974 non-null   object
#  4   ZONENAME         3968 non-null   object
#  5   LONGITUDE        3974 non-null   float64
#  6   LATITUDE         3974 non-null   float64
#  7   REGION           3974 non-null   object
#  8   AREA             3951 non-null   object
#  9   CELL_ID          13976 non-null  object
#  10  SITE_CODE        3974 non-null   object
#  11  PRODUTC          5001 non-null   object
#  12  VALUE            15003 non-null  float64
#  13  DATETIME         5001 non-null   object
#  14  CELL_ON_SITE     15003 non-null  object
#  15  DW_A_NUMBER_INT  10002 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# VILLES             15003
# STATUS             15070
# LOCALISATION       15003
# DECOUPZONE         15003
# ZONENAME           15009
# LONGITUDE          15003
# LATITUDE           15003
# REGION             15003
# AREA               15026
# CELL_ID             5001
# SITE_CODE          15003
# PRODUTC            13976
# VALUE               3974
# DATETIME           13976
# CELL_ON_SITE        3974
# DW_A_NUMBER_INT     8975
# DW_B_NUMBER_INT     8975
# COUNTRY_A           3974
# COUNTRY_B           3974
# SITE_ID            10367
# dtype: int64

# %%
df1[df1.PRODUTC.isnull()]
# Out:
#        VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  LONGITUDE  \
# 0      ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 1      ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 2      ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 3     ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# 4     ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# ...       ...         ...          ...           ...       ...        ...
# 4996      NaN         NaN          NaN           NaN       NaN        NaN
# 4997      NaN         NaN          NaN           NaN       NaN        NaN
# 4998      NaN         NaN          NaN           NaN       NaN        NaN
# 4999      NaN         NaN          NaN           NaN       NaN        NaN
# 5000      NaN         NaN          NaN           NaN       NaN        NaN
#
#       LATITUDE     REGION AREA     CELL_ID   SITE_CODE PRODUTC  VALUE  \
# ...

# %%
df1['PRODUTC'].value_counts(dropna=False)
# Out:
# NaN      13976
# Voice     2219
# sms       1975
# data       807
# Name: PRODUTC, dtype: int64

# %%
df1['PRODUTC'].fillna(value='Voice', inplace=True)

# %%
df1.head(60)
# Out:
#          VILLES      STATUS LOCALISATION       DECOUPZONE  \
# 0        ADJAME  In Service      ABIDJAN     "Abidjan_EST
# 1        ADJAME  In Service      ABIDJAN     "Abidjan_EST
# 2        ADJAME  In Service      ABIDJAN     "Abidjan_EST
# 3       ASSINIE  In Service    INTERIEUR        Grand-EST
# 4       ASSINIE  In Service    INTERIEUR        Grand-EST
# 5       ASSINIE  In Service    INTERIEUR        Grand-EST
# 6      KRIKOREA  In Service    INTERIEUR      Grand-OUEST
# 7         ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 8         ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 9         ABOBO         NaN      ABIDJAN    "Abidjan_NORD
# 10        ABOBO         NaN      ABIDJAN    "Abidjan_NORD
# 11        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 12        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 13        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# 14        ABOBO  In Service      ABIDJAN    "Abidjan_NORD
# ...

# %%
df1.describe()
# Out:
#          LONGITUDE     LATITUDE         VALUE
# count  3974.000000  3974.000000  15003.000000
# mean     -4.877659     6.244749     25.548690
# std       1.300771     1.304199    152.916219
# min      -8.503889     0.000000      0.000000
# 25%      -5.846139     5.338639      0.000000
# 50%      -4.084500     5.475000      0.000000
# 75%      -3.993444     6.872306     25.000000
# max      -0.000000    10.481861  12900.000000

# %% [markdown]
# ###1.0 Which ones were the most used city for the three days?

# %% [markdown]
# ###2.0 Which cities were the most used during business and home hours?

# %% [markdown]
# ###3.0 Most used city for the three days?

# %%
for i in zip(df1['VILLES'],df1['VALUE']):
    #print(i)
    if i[1]==12900:
        print(i[0])
# Out:
# nan
